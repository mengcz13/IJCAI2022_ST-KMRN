# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pems_bay = pd.read_hdf('../../data/pems/pems-bay.h5')

# %%
pems_bay = np.load('../../data/pems/dense_multires/PEMS-BAY/sampled_dense_multires_seqs.npz', allow_pickle=True)
list(pems_bay.keys())
# Out:
# ['train_seq',
#  'train_time',
#  'train_time_abs',
#  'val_seq',
#  'val_time',
#  'val_time_abs',
#  'test_seq',
#  'test_time',
#  'test_time_abs',
#  'resolution_steps',
#  'input_ts_max']

# %%
pems_bay[:3]
# Out:
# sensor_id            400001  400017  400030  400040  400045  400052  400057  \
# 2017-01-01 00:00:00    71.4    67.8    70.5    67.4    68.8    66.6    66.8
# 2017-01-01 00:05:00    71.6    67.5    70.6    67.5    68.7    66.6    66.8
# 2017-01-01 00:10:00    71.6    67.6    70.2    67.4    68.7    66.1    66.8
#
# sensor_id            400059  400065  400069  ...  409525  409526  409528  \
# 2017-01-01 00:00:00    68.0    66.8    69.0  ...    68.8    67.9    68.8
# 2017-01-01 00:05:00    67.8    66.5    68.2  ...    68.4    67.3    68.4
# 2017-01-01 00:10:00    67.8    66.2    67.8  ...    68.4    67.4    68.4
#
# sensor_id            409529  413026  413845  413877  413878  414284  414694
# 2017-01-01 00:00:00    68.0    69.2    68.9    70.4    68.8    71.1    68.0
# 2017-01-01 00:05:00    67.6    70.4    68.8    70.1    68.4    70.8    67.4
# 2017-01-01 00:10:00    67.5    70.2    68.3    69.8    68.4    70.5    67.9
#
# [3 rows x 325 columns]

# %%
pems_bay_values = pems_bay.values

# %%
pems_bay_values.shape
# Out:
# (52116, 325)

# %%
node_i = 2
node_seq = pems_bay_values[:, node_i].reshape(-1, 1)
print(node_seq.shape)

fig, ax = plt.subplots(figsize=(20, 5))
ax.plot(node_seq[:, 0])
ax.set_ylim(0, 80)
ax.set_title('Whole Seq')

fig, ax = plt.subplots(figsize=(20, 5))
ax.plot(node_seq[288*7:288*9, 0])
ax.set_ylim(0, 80)
ax.set_title('Two Days')

fig, ax = plt.subplots(figsize=(20, 5))
ax.plot(node_seq[288*7*3:288*7*4, 0])
ax.set_ylim(0, 80)
ax.set_title('Two Weeks')

fig, ax = plt.subplots(figsize=(20, 5))
ax.plot(node_seq[:288*60, 0])
ax.set_ylim(0, 80)
ax.set_title('Two Months')

fig, ax = plt.subplots(figsize=(20, 5))
ax.plot(node_seq[:288*180, 0])
ax.set_ylim(0, 80)
ax.set_title('Six Months')
# Out:
# (52116, 1)
# Text(0.5, 1.0, 'Six Months')
